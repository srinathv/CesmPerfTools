# %%
import os,sys,gzip
sys.path.append('../modules')
import cesmperftiming as cpt
import cesmperfplotting as cpp
import numpy as np
import pandas as pd

# %%
pathToStampedePerfData='/Users/srinathv/Repos/stampede-c13b07.perl-scripts/'

# %%
pd.__version__
# Out:
# '0.13.1'

# %%
data1file='fc5.host.2nodes.16mpi.NoOmp/timing/ccsm_timing_stats.140506-133854.gz'

# %%
pd.read_table(pathToStampedePerfData+data1file, compression='gzip',skiprows=range(5), sep='\s+')
# Out:
#                            name  processes  threads   count     walltotal  \
# 0                   DRIVER_INIT         32       32      32    648.706200
# 1             driver_init_comps         32       32      32    564.592300
# 2                phys_grid_init         32       32      32      0.844621
# 3              driver_init_maps         32       32      32     13.309180
# 4           driver_init_atminit         32       32    7872      2.817016
# 5                   stepon_run1         32       32    7744     70.305710
# 6                  d_p_coupling         32       32    7744     70.291070
# 7                  UniquePoints         32       32    7744     18.987160
# 8                        dpcopy         32       32    7744     23.687240
# 9                  derived_phys         32       32    7744     27.322460
# 10                    phys_run1         32       32    7744   6393.058000
# 11                  physpkg_st1         32       32   15488     99.713950
# ...
