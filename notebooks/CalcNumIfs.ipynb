# %%
file=open('../test/fortranFilesWithIfCount.txt')
lines=file.readlines()
print lines
# Out:
# ['ChangeLog:92\n', 'ChangeLog_template:2\n', 'Copyright:0\n', 'models/drv/shr_esmf/esmfshr_util_mod.F90:16\n', 'models/drv/shr_esmf/esmfshr_mod.F90:0\n', 'models/drv/shr_esmf/esmfshr_attribute_mod.F90:3\n', 'models/drv/shr_esmf/esmfshr_infodata_mod.F90:116\n', 'models/drv/shr_esmf/esmf2mct_mod.F90:5\n', 'models/drv/shr_esmf/mct2esmf_mod.F90:6\n', 'models/drv/driver/prep_wav_mod.F90:9\n', 'models/drv/driver/seq_domain_mct.F90:64\n', 'models/drv/driver/prep_aoflux_mod.F90:7\n', 'models/drv/driver/seq_rest_mod.F90:27\n', 'models/drv/driver/seq_map_mod.F90:81\n', 'models/drv/driver/seq_map_type_mod.F90:12\n', 'models/drv/driver/prep_ice_mod.F90:10\n', 'models/drv/driver/seq_frac_mct.F90:80\n', 'models/drv/driver/seq_flux_mct.F90:27\n', 'models/drv/driver/prep_glc_mod.F90:4\n', 'models/drv/driver/cplcomp_exchange_mod.F90:72\n', 'models/drv/driver/seq_map_esmf.F90:4\n', 'models/drv/driver/t_driver_timers_mod.F90:13\n', 'models/drv/driver/ccsm_driver.F90:6\n', 'models/drv/driver/component_m
# ...

# %%
ifLinesCount=0
for i in lines:
    count=i.split(':')[1]
    #print count
    ifLinesCount += int(count)
print 'ifLinesCount = ', ifLinesCount
# Out:
# ifLinesCount =  60422

# %%
60422/1409152.
# Out:
# 0.04287827005177582
